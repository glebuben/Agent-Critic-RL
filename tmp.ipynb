# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
metrics = np.load("checkpoints/20260325_023422/training_metrics.npz")

# %%
metrics
# Out:
# NpzFile 'checkpoints/20260325_023422/training_metrics.npz' with keys: n_steps, episode_returns, total_distances

# %%
plt.plot(metrics["n_steps"], metrics["episode_returns"], alpha = 0.3)
plt.xlabel("Environment Steps")
plt.ylabel("Episode Returns")
plt.title("Training Progress")
plt.show()
